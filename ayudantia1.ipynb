# %% [markdown]
# <a href="https://colab.research.google.com/github/FabianAlexanderCabezasTorres/U/blob/main/ayudantia1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#include <stdio.h>

int main(){
    int c, ele;

    printf("Ingresa una opción (1-5) y luego presiona ENTER: ");
    ele = getchar() - '0';
    getchar(); // Esto limpia el salto de línea (Enter) de la memoria

    printf("Ingresa un número: ");
    if((c = getchar()) != EOF) {
        printf("El valor antes de operar es: %d\n", c);
    }

    /*
      Implemente aqui cada operación
      (ZONA 1: AQUÍ DEBES ESCRIBIR TU LÓGICA)
    */

    printf("El valor final es: ");
    if (ele == 4 || ele == 5){
        //completar (ZONA 2: SALIDA DE TEXTO)
    } else {
        //completar (ZONA 3: SALIDA NUMÉRICA)
    }

    return 0;
}
